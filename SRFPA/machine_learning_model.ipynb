# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('D:\Python_Proj\Singapore resale flat price\combined.csv')
df
# Out:
#         latitude   longitude blk_no             road_name  postal_code  \
# 0       1.366197  103.841505    216   ANG MO KIO AVENUE 1       560216
# 1       1.366197  103.841505    216   ANG MO KIO AVENUE 1       560216
# 2       1.366197  103.841505    216   ANG MO KIO AVENUE 1       560216
# 3       1.366197  103.841505    216   ANG MO KIO AVENUE 1       560216
# 4       1.366197  103.841505    216   ANG MO KIO AVENUE 1       560216
# ...          ...         ...    ...                   ...          ...
# 222701  1.445029  103.829460   118B     CANBERRA CRESCENT       752118
# 222702  1.445029  103.829460   118B     CANBERRA CRESCENT       752118
# 222703  1.391577  103.870445   455A  SENGKANG WEST AVENUE       791455
# 222704  1.444637  103.829635   118A     CANBERRA CRESCENT       751118
# 222705  1.444796  103.830160   117B     CANBERRA CRESCENT       752117
#
#                        address      cbd_dist  min_dist_mrt    month  \
# 0         216 ANG MO KIO AVE 1   9263.833118    994.161669  2015-09
# 1         216 ANG MO KIO AVE 1   9263.833118    994.161669  2016-08
# 2         216 ANG MO KIO AVE 1   9263.833118    994.161669  2016-08
# 3         216 ANG MO KIO AVE 1   9263.833118    994.161669  2016-08
# 4         216 ANG MO KIO AVE 1   9263.833118    994.161669  2017-03
# ...                        ...           ...           ...      ...
# 222701      118B CANBERRA CRES  18080.394744   1140.326560  2024-07
# 222702      118B CANBERRA CRES  18080.394744   1140.326560  2024-07
# 222703  455A SENGKANG WEST AVE  12193.435573    648.695537  2024-06
# 222704      118A CANBERRA CRES  18034.887863   1175.809037  2024-07
# 222705      117B CANBERRA CRES  18044.574080   1221.974051  2024-07
#
#               town flat_type block        street_name storey_range  \
# 0       ANG MO KIO    3 ROOM   216   ANG MO KIO AVE 1     07 TO 09
# 1       ANG MO KIO    3 ROOM   216   ANG MO KIO AVE 1     07 TO 09
# 2       ANG MO KIO    3 ROOM   216   ANG MO KIO AVE 1     10 TO 12
# 3       ANG MO KIO    3 ROOM   216   ANG MO KIO AVE 1     04 TO 06
# 4       ANG MO KIO    3 ROOM   216   ANG MO KIO AVE 1     07 TO 09
# ...            ...       ...   ...                ...          ...
# 222701   SEMBAWANG    4 ROOM  118B      CANBERRA CRES     10 TO 12
# 222702   SEMBAWANG    4 ROOM  118B      CANBERRA CRES     07 TO 09
# 222703    SENGKANG    2 ROOM  455A  SENGKANG WEST AVE     01 TO 03
# 222704   SEMBAWANG    2 ROOM  118A      CANBERRA CRES     10 TO 12
# 222705   SEMBAWANG    4 ROOM  117B      CANBERRA CRES     07 TO 09
#
#         floor_area_sqm      flat_model  lease_commence_date  resale_price  \
# 0                 73.0  New Generation                 1976      317000.0
# 1                 73.0  New Generation                 1976      308000.0
# 2                 73.0  New Generation                 1976      318000.0
# 3                 73.0  New Generation                 1976      325000.0
# 4                 73.0  New Generation                 1976      310000.0
# ...                ...             ...                  ...           ...
# 222701            92.0         Model A                 2020      735000.0
# 222702            95.0         Model A                 2020      725600.0
# 222703            48.0          2-room                 2020      350000.0
# 222704            47.0         Model A                 2020      418000.0
# 222705            92.0         Model A                 2020      730000.0
#
#            remaining_lease  lease_remain_years
# 0                       59                  52
# 1                       58                  52
# 2                       58                  52
# 3                       58                  52
# 4        58 years 01 month                  52
# ...                    ...                 ...
# 222701  94 years 11 months                  96
# 222702  94 years 11 months                  96
# 222703  95 years 05 months                  96
# 222704  94 years 11 months                  96
# 222705  94 years 11 months                  96
#
# [222706 rows x 20 columns]

# %%
df.dtypes
# Out:
# latitude               float64
# longitude              float64
# blk_no                  object
# road_name               object
# postal_code              int64
# address                 object
# cbd_dist               float64
# min_dist_mrt           float64
# month                   object
# town                    object
# flat_type               object
# block                   object
# street_name             object
# storey_range            object
# floor_area_sqm         float64
# flat_model              object
# lease_commence_date      int64
# resale_price           float64
# remaining_lease         object
# lease_remain_years       int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# latitude               0
# longitude              0
# blk_no                 0
# road_name              0
# postal_code            0
# address                0
# cbd_dist               0
# min_dist_mrt           0
# month                  0
# town                   0
# flat_type              0
# block                  0
# street_name            0
# storey_range           0
# floor_area_sqm         0
# flat_model             0
# lease_commence_date    0
# resale_price           0
# remaining_lease        0
# lease_remain_years     0
# dtype: int64

# %%
import statistics

def get_median(x):
    split_list = x.split(' TO ')
    float_list = [float(i) for i in split_list]
    median = statistics.median(float_list)
    return median

df['storey_median'] = df['storey_range'].apply(lambda x: get_median(x))
df
# Out:
#         latitude   longitude blk_no             road_name  postal_code  \
# 0       1.366197  103.841505    216   ANG MO KIO AVENUE 1       560216
# 1       1.366197  103.841505    216   ANG MO KIO AVENUE 1       560216
# 2       1.366197  103.841505    216   ANG MO KIO AVENUE 1       560216
# 3       1.366197  103.841505    216   ANG MO KIO AVENUE 1       560216
# 4       1.366197  103.841505    216   ANG MO KIO AVENUE 1       560216
# ...          ...         ...    ...                   ...          ...
# 222701  1.445029  103.829460   118B     CANBERRA CRESCENT       752118
# 222702  1.445029  103.829460   118B     CANBERRA CRESCENT       752118
# 222703  1.391577  103.870445   455A  SENGKANG WEST AVENUE       791455
# 222704  1.444637  103.829635   118A     CANBERRA CRESCENT       751118
# 222705  1.444796  103.830160   117B     CANBERRA CRESCENT       752117
#
#                        address      cbd_dist  min_dist_mrt    month  \
# 0         216 ANG MO KIO AVE 1   9263.833118    994.161669  2015-09
# 1         216 ANG MO KIO AVE 1   9263.833118    994.161669  2016-08
# 2         216 ANG MO KIO AVE 1   9263.833118    994.161669  2016-08
# 3         216 ANG MO KIO AVE 1   9263.833118    994.161669  2016-08
# 4         216 ANG MO KIO AVE 1   9263.833118    994.161669  2017-03
# ...                        ...           ...           ...      ...
# 222701      118B CANBERRA CRES  18080.394744   1140.326560  2024-07
# 222702      118B CANBERRA CRES  18080.394744   1140.326560  2024-07
# 222703  455A SENGKANG WEST AVE  12193.435573    648.695537  2024-06
# 222704      118A CANBERRA CRES  18034.887863   1175.809037  2024-07
# 222705      117B CANBERRA CRES  18044.574080   1221.974051  2024-07
#
#               town  ... block        street_name storey_range floor_area_sqm  \
# 0       ANG MO KIO  ...   216   ANG MO KIO AVE 1     07 TO 09           73.0
# 1       ANG MO KIO  ...   216   ANG MO KIO AVE 1     07 TO 09           73.0
# 2       ANG MO KIO  ...   216   ANG MO KIO AVE 1     10 TO 12           73.0
# 3       ANG MO KIO  ...   216   ANG MO KIO AVE 1     04 TO 06           73.0
# 4       ANG MO KIO  ...   216   ANG MO KIO AVE 1     07 TO 09           73.0
# ...            ...  ...   ...                ...          ...            ...
# 222701   SEMBAWANG  ...  118B      CANBERRA CRES     10 TO 12           92.0
# 222702   SEMBAWANG  ...  118B      CANBERRA CRES     07 TO 09           95.0
# 222703    SENGKANG  ...  455A  SENGKANG WEST AVE     01 TO 03           48.0
# 222704   SEMBAWANG  ...  118A      CANBERRA CRES     10 TO 12           47.0
# 222705   SEMBAWANG  ...  117B      CANBERRA CRES     07 TO 09           92.0
#
#             flat_model lease_commence_date  resale_price     remaining_lease  \
# 0       New Generation                1976      317000.0                  59
# 1       New Generation                1976      308000.0                  58
# 2       New Generation                1976      318000.0                  58
# 3       New Generation                1976      325000.0                  58
# 4       New Generation                1976      310000.0   58 years 01 month
# ...                ...                 ...           ...                 ...
# 222701         Model A                2020      735000.0  94 years 11 months
# 222702         Model A                2020      725600.0  94 years 11 months
# 222703          2-room                2020      350000.0  95 years 05 months
# 222704         Model A                2020      418000.0  94 years 11 months
# 222705         Model A                2020      730000.0  94 years 11 months
#
#        lease_remain_years  storey_median
# 0                      52            8.0
# 1                      52            8.0
# 2                      52           11.0
# 3                      52            5.0
# 4                      52            8.0
# ...                   ...            ...
# 222701                 96           11.0
# 222702                 96            8.0
# 222703                 96            2.0
# 222704                 96           11.0
# 222705                 96            8.0
#
# [222706 rows x 21 columns]

# %%
scope_df = df[['cbd_dist','min_dist_mrt','floor_area_sqm','lease_remain_years','storey_median','resale_price']]
scope_df
# Out:
#             cbd_dist  min_dist_mrt  floor_area_sqm  lease_remain_years  \
# 0        9263.833118    994.161669            73.0                  52
# 1        9263.833118    994.161669            73.0                  52
# 2        9263.833118    994.161669            73.0                  52
# 3        9263.833118    994.161669            73.0                  52
# 4        9263.833118    994.161669            73.0                  52
# ...              ...           ...             ...                 ...
# 222701  18080.394744   1140.326560            92.0                  96
# 222702  18080.394744   1140.326560            95.0                  96
# 222703  12193.435573    648.695537            48.0                  96
# 222704  18034.887863   1175.809037            47.0                  96
# 222705  18044.574080   1221.974051            92.0                  96
#
#         storey_median  resale_price
# 0                 8.0      317000.0
# 1                 8.0      308000.0
# 2                11.0      318000.0
# 3                 5.0      325000.0
# 4                 8.0      310000.0
# ...               ...           ...
# 222701           11.0      735000.0
# 222702            8.0      725600.0
# 222703            2.0      350000.0
# 222704           11.0      418000.0
# 222705            8.0      730000.0
#
# [222706 rows x 6 columns]

# %%
scope_df = scope_df.drop_duplicates()
scope_df
# Out:
#             cbd_dist  min_dist_mrt  floor_area_sqm  lease_remain_years  \
# 0        9263.833118    994.161669            73.0                  52
# 1        9263.833118    994.161669            73.0                  52
# 2        9263.833118    994.161669            73.0                  52
# 3        9263.833118    994.161669            73.0                  52
# 4        9263.833118    994.161669            73.0                  52
# ...              ...           ...             ...                 ...
# 222701  18080.394744   1140.326560            92.0                  96
# 222702  18080.394744   1140.326560            95.0                  96
# 222703  12193.435573    648.695537            48.0                  96
# 222704  18034.887863   1175.809037            47.0                  96
# 222705  18044.574080   1221.974051            92.0                  96
#
#         storey_median  resale_price
# 0                 8.0      317000.0
# 1                 8.0      308000.0
# 2                11.0      318000.0
# 3                 5.0      325000.0
# 4                 8.0      310000.0
# ...               ...           ...
# 222701           11.0      735000.0
# 222702            8.0      725600.0
# 222703            2.0      350000.0
# 222704           11.0      418000.0
# 222705            8.0      730000.0
#
# [215957 rows x 6 columns]

# %% [markdown]
# Skewness

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# List of columns(continuous variables) for finding skewness
col = ['cbd_dist','min_dist_mrt','floor_area_sqm','lease_remain_years','storey_median','resale_price']

for i in col:
    plt.figure(figsize=(8, 6))  
    sns.boxplot(data=df, x=i)
    plt.title(f'Boxplot of {i}')
    plt.xlabel(i)
    plt.show()

# %% [markdown]
# Lograthimic transformation

# %%
df1 = scope_df

# %%
df1['floor_area_sqm'] = np.log(df1['floor_area_sqm'])
sns.boxplot(x='floor_area_sqm', data=df1)
plt.show()

df1['storey_median'] = np.log(df1['storey_median'])
sns.boxplot(x='storey_median', data=df1)
plt.show()

df1['resale_price'] = np.log(df1['resale_price'])
sns.boxplot(x='resale_price', data=df1)
plt.show()

# %%
df1.dtypes
# Out:
# cbd_dist              float64
# min_dist_mrt          float64
# floor_area_sqm        float64
# lease_remain_years      int64
# storey_median         float64
# resale_price          float64
# dtype: object

# %% [markdown]
# Visualization - Correlation method

# %%
import seaborn as sns

corrMatrix = df1.corr()
plt.figure(figsize=(15, 10))
plt.title("Correlation Heatmap")
sns.heatmap(
    corrMatrix, 
    xticklabels=corrMatrix.columns,
    yticklabels=corrMatrix.columns,
    cmap='RdBu', 
    annot=True
)
# Out:
# <Axes: title={'center': 'Correlation Heatmap'}>

# %% [markdown]
# Encoding - Standard scaler

# %%
from sklearn.preprocessing import StandardScaler

X=df1[['cbd_dist','min_dist_mrt','floor_area_sqm','lease_remain_years','storey_median']]
y=df1['resale_price']

# Normalizing the encoded data
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
test_dataframe = pd.DataFrame(X)
test_dataframe
# Out:
#                0         1         2         3         4
# 0      -0.726183  0.779607 -0.999540 -1.410400  0.212051
# 1      -0.726183  0.779607 -0.999540 -1.410400  0.212051
# 2      -0.726183  0.779607 -0.999540 -1.410400  0.655284
# 3      -0.726183  0.779607 -0.999540 -1.410400 -0.442113
# 4      -0.726183  0.779607 -0.999540 -1.410400  0.212051
# ...          ...       ...       ...       ...       ...
# 215952  1.278434  1.122999 -0.098546  1.811297  0.655284
# 215953  1.278434  1.122999  0.026433  1.811297  0.212051
# 215954 -0.060081 -0.032014 -2.632492  1.811297 -1.717431
# 215955  1.268087  1.206360 -2.714492  1.811297  0.655284
# 215956  1.270290  1.314818 -0.098546  1.811297  0.212051
#
# [215957 rows x 5 columns]

# %% [markdown]
# Training and Testing

# %%
from sklearn.model_selection import train_test_split

# test and train split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %% [markdown]
# Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import GridSearchCV

# Decision Tree Regressor
dtr = DecisionTreeRegressor()

# hyperparameters
param_grid = {
    'max_depth': [2, 5, 10, 15, 20, 22],
    'min_samples_split': [2, 3, 4, 5],
    'min_samples_leaf': [2, 3, 4, 5, 6, 7, 8, 9, 10, 15, 20],
    'max_features': ['auto', 'sqrt', 'log2']
}

# gridsearchcv
grid_search = GridSearchCV(estimator=dtr, param_grid=param_grid, cv=5)
grid_search.fit(X_train, y_train)
print("Best hyperparameters:", grid_search.best_params_)
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)

# evalution metrics
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print(" ")
print('Mean squared error:', mse)
print('Mean Absolute Error', mae)
print('Root Mean squared error:', rmse)
print(" ")
print('R-squared:', r2)
# Out:
# Best hyperparameters: {'max_depth': 22, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 3}
#
# Mean squared error: 0.018173587533552374
# Mean Absolute Error 0.10821769502933254
# Root Mean squared error: 0.13480944897725966
#
# R-squared: 0.8357079878617266

# %%
new_sample = np.array([[8740, 999, np.log(44), 55, np.log(11)]])
new_sample = scaler.transform(new_sample[:, :5])
new_pred = best_model.predict(new_sample)[0]
np.exp(new_pred)
# Out:
# 274102.7321760077

# %%
# Saving the model
import pickle
with open('model.pkl', 'wb') as file:
    pickle.dump(best_model, file)

with open('scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)
